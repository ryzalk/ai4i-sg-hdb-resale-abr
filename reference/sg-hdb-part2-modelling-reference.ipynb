# %% [markdown]
# <img src="https://gallery.mailchimp.com/f98d5ac0a3fbbdcdda35136ab/images/2002af76-5fd4-4185-9d49-28558b6b8772.png">

# %% [markdown]
# # `sg-hdb-resale-abr`
# # Part 2: Model Training
# What we have done so far is to extract data from the .csv files, do some preliminary transformation to the data, and then loading all of it into an SQLite database. The next step is to work towards creating a simple predictive model for us to predict the price of a resale HDB unit. The following cells will have us load data from the SQLite database, that we have previously created.

# %%
# Import relevant packages
import pandas as pd
from sqlalchemy import create_engine

# %%
# Initialise engine
sql_engine = create_engine('sqlite:///../data/processed/sg_hdb.db')
# Simple query to get the whole table
query = "SELECT * FROM sg_hdb_resale"
# Store result of query in a pandas dataframe
sg_hdb_resale_df = pd.read_sql_query(query, sql_engine)

# %%
# NOTE: If the cell above did not work for you, you can uncomment the following lines to query from a database that has been prepared beforehand
# sql_engine = create_engine('sqlite:///../reference/sg_hdb.db')
# query = "SELECT * FROM sg_hdb_resale"
# sg_hdb_resale_df = pd.read_sql_query(query, sql_engine)

# %%
# Observe result of query executed
sg_hdb_resale_df
# Out:
#             id block      flat_model  flat_type  floor_area_sqm  \
# 0            0   309        improved     1 ROOM            31.0
# 1            1   309        improved     1 ROOM            31.0
# 2            2   309        improved     1 ROOM            31.0
# 3            3   309        improved     1 ROOM            31.0
# 4            4   216  new generation     3 ROOM            73.0
# 5            5   211  new generation     3 ROOM            67.0
# 6            6   202  new generation     3 ROOM            67.0
# 7            7   235  new generation     3 ROOM            67.0
# 8            8   235  new generation     3 ROOM            67.0
# 9            9   232  new generation     3 ROOM            67.0
# 10          10   232  new generation     3 ROOM            67.0
# 11          11   308  new generation     3 ROOM            82.0
# 12          12   308  new generation     3 ROOM            67.0
# 13          13   220  new generation     3 ROOM            67.0
# 14          14   219  new generation     3 ROOM            82.0
# 15          15   247  new generation     3 ROOM            82.0
# 16          16   320  new generation     3 ROOM            73.0
# 17          17   252  new generation     3 ROOM            67.0
# 18          18   223  new generation     3 ROOM            67.0
# 19          19   223  new generation     3 ROOM            67.0
# 20          20   230  new generation     3 ROOM            82.0
# 21          21   329  new generation     3 ROOM            73.0
# 22          22   313  new generation     3 ROOM            73.0
# 23          23   117  new generation     3 ROOM            74.0
# 24          24   110  new generation     3 ROOM            67.0
# 25          25   343  new generation     3 ROOM            73.0
# 26          26   345  new generation     3 ROOM            73.0
# 27          27   346  new generation     3 ROOM            73.0
# 28          28   121  new generation     3 ROOM            67.0
# 29          29   129  new generation     3 ROOM            73.0
# ...        ...   ...             ...        ...             ...
# 790613  790613   329      simplified     4 ROOM            84.0
# 790614  790614   366         model a     4 ROOM           108.0
# 790615  790615   216  new generation     4 ROOM            93.0
# 790616  790616   259      simplified     4 ROOM            84.0
# 790617  790617   260      simplified     4 ROOM            84.0
# 790618  790618   609      simplified     4 ROOM            84.0
# 790619  790619   637      simplified     4 ROOM            85.0
# 790620  790620   721         model a     4 ROOM           104.0
# 790621  790621   876      simplified     4 ROOM            88.0
# 790622  790622   850         model a     4 ROOM           104.0
# 790623  790623   868      simplified     4 ROOM            84.0
# 790624  790624   868      simplified     4 ROOM            84.0
# 790625  790625   821         model a     4 ROOM           104.0
# 790626  790626   821         model a     4 ROOM           104.0
# 790627  790627   733        improved     5 ROOM           123.0
# 790628  790628   170        improved     5 ROOM           131.0
# 1          04 TO 06  ANG MO KIO AVE 1  ANG MO KIO
# 2          10 TO 12  ANG MO KIO AVE 1  ANG MO KIO
# 3          07 TO 09  ANG MO KIO AVE 1  ANG MO KIO
# 4          04 TO 06  ANG MO KIO AVE 1  ANG MO KIO
# 5          01 TO 03  ANG MO KIO AVE 3  ANG MO KIO
# 6          07 TO 09  ANG MO KIO AVE 3  ANG MO KIO
# 7          10 TO 12  ANG MO KIO AVE 3  ANG MO KIO
# 8          04 TO 06  ANG MO KIO AVE 3  ANG MO KIO
# 9          01 TO 03  ANG MO KIO AVE 3  ANG MO KIO
# 10         07 TO 09  ANG MO KIO AVE 3  ANG MO KIO
# 11         07 TO 09  ANG MO KIO AVE 1  ANG MO KIO
# 12         10 TO 12  ANG MO KIO AVE 1  ANG MO KIO
# 13         07 TO 09  ANG MO KIO AVE 1  ANG MO KIO
# 14         07 TO 09  ANG MO KIO AVE 1  ANG MO KIO
# 15         04 TO 06  ANG MO KIO AVE 3  ANG MO KIO
# 16         07 TO 09  ANG MO KIO AVE 1  ANG MO KIO
# 17         07 TO 09  ANG MO KIO AVE 4  ANG MO KIO
# 18         04 TO 06  ANG MO KIO AVE 1  ANG MO KIO
# 19         10 TO 12  ANG MO KIO AVE 1  ANG MO KIO
# 20         07 TO 09  ANG MO KIO AVE 3  ANG MO KIO
# 21         07 TO 09  ANG MO KIO AVE 3  ANG MO KIO
# 22         10 TO 12  ANG MO KIO AVE 3  ANG MO KIO
# 23         04 TO 06  ANG MO KIO AVE 4  ANG MO KIO
# 24         10 TO 12  ANG MO KIO AVE 4  ANG MO KIO
# 25         07 TO 09  ANG MO KIO AVE 3  ANG MO KIO
# 26         04 TO 06  ANG MO KIO AVE 3  ANG MO KIO
# 27         10 TO 12  ANG MO KIO AVE 3  ANG MO KIO
# 28         04 TO 06  ANG MO KIO AVE 3  ANG MO KIO
# 29         04 TO 06  ANG MO KIO AVE 3  ANG MO KIO
# ...             ...               ...         ...
# 790613     04 TO 06    YISHUN RING RD      YISHUN
# 790614     07 TO 09    YISHUN RING RD      YISHUN
# 790615     10 TO 12      YISHUN ST 21      YISHUN
# 790616     07 TO 09      YISHUN ST 22      YISHUN
# 790617     04 TO 06      YISHUN ST 22      YISHUN
# 790618     04 TO 06      YISHUN ST 61      YISHUN
# 790619     10 TO 12      YISHUN ST 61      YISHUN
# 790620     07 TO 09      YISHUN ST 71      YISHUN
# 790621     01 TO 03      YISHUN ST 81      YISHUN
# 790622     01 TO 03      YISHUN ST 81      YISHUN
# 790623     04 TO 06      YISHUN ST 81      YISHUN
# 790624     01 TO 03      YISHUN ST 81      YISHUN
# 790625     04 TO 06      YISHUN ST 81      YISHUN
# 790626     04 TO 06      YISHUN ST 81      YISHUN
# 790627     01 TO 03      YISHUN AVE 5      YISHUN
# 790628     04 TO 06      YISHUN AVE 7      YISHUN
# 790629     04 TO 06     YISHUN CTRL 1      YISHUN
# 790630     13 TO 15    YISHUN RING RD      YISHUN
# 790631     01 TO 03    YISHUN RING RD      YISHUN
# 790632     10 TO 12      YISHUN ST 20      YISHUN
# 790633     01 TO 03      YISHUN ST 21      YISHUN
# 790634     04 TO 06      YISHUN ST 61      YISHUN
# 790635     01 TO 03      YISHUN ST 71      YISHUN
# 790636     01 TO 03      YISHUN ST 72      YISHUN
# 790637     01 TO 03      YISHUN ST 81      YISHUN
# 790638     10 TO 12      YISHUN ST 81      YISHUN
# 790639     10 TO 12       YISHUN CTRL      YISHUN
# 790640     07 TO 09    YISHUN RING RD      YISHUN
# 790641     07 TO 09      YISHUN ST 22      YISHUN
# 790642     04 TO 06      YISHUN ST 22      YISHUN
#
# [790643 rows x 12 columns]

# %% [markdown]
# We are first going to inspect the data types of the imported dataframe.

# %%
sg_hdb_resale_df.dtypes
# Out:
# id                       int64
# block                   object
# flat_model              object
# flat_type               object
# floor_area_sqm         float64
# lease_commence_date      int64
# month                   object
# remaining_lease          int64
# resale_price           float64
# storey_range            object
# street_name             object
# town                    object
# dtype: object

# %% [markdown]
# Now, we create 2 separate series containing the predictor and response values to train our model on.

# %%
sg_hdb_x = sg_hdb_resale_df['floor_area_sqm'].values
sg_hdb_y = sg_hdb_resale_df['resale_price'].values

# %%
# Import the relevant packages
import numpy as np
import sklearn
from sklearn import model_selection
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import pickle

# %% [markdown]
# When training a model, we have to create a train-test split to check the accuracy/performance of the model.

# %%
sg_hdb_x_train, sg_hdb_x_test, sg_hdb_y_train, sg_hdb_y_test = sklearn.model_selection.train_test_split(
    sg_hdb_x, sg_hdb_y,
    test_size=0.3, random_state=7
)

# %%
# Reshaping needed when using a single variable for predictor
sg_hdb_x_train = sg_hdb_x_train.reshape(-1,1)
sg_hdb_x_test = sg_hdb_x_test.reshape(-1,1)

# %% [markdown]
# We are gonna create a simple linear regression model (a.k.a best fit line) from the dataset.

# %%
# Initialise model
lm = LinearRegression()
# Create model from the train sets
lm.fit(sg_hdb_x_train, sg_hdb_y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# To observe the model's coefficients
print('Coefficients: \n X:', lm.coef_,'\n c:', lm.intercept_)
# Out:
# Coefficients:
#  X: [3518.48113445]
#  c: -49415.00329505844

# %% [markdown]
# Y = mX + C

# %% [markdown]
# After creating the model, we are going to evaluate its performance by pitting it against the test set.
#
# First, we use the linear model to provide us with the predictions derived from the values in the test set.

# %%
sg_hdb_y_pred = lm.predict(sg_hdb_x_test)
sg_hdb_y_pred
# Out:
# array([186323.23271299, 217989.56292303, 179286.2704441 , ...,
#        376321.21397321, 316507.03468759, 207434.11951968])

# %% [markdown]
# Thereafter, we are going to calculate the errors, pitting the predicted values with actual historical values.

# %%
# Examine fitness of model
r2_score(sg_hdb_y_test, sg_hdb_y_pred)
# Out:
# 0.3994763162246405

# %% [markdown]
# Well, we did little to create a good model, hence the low value of fitness.
#
# For the sake of this exercise, let us just proceed and export (serialise) this model for deployment. Save the model under a name, for example like the one below: 'sg_hdb_lm_v1.pkl'

# %%
# Specify output location of model to be serialised
file_loc_name = '../models/sg_hdb_lm_v1.pkl'
pickle.dump(lm, open(file_loc_name, 'wb'))

# %% [markdown]
# Here, we just do a quick test by loading the model and then doing a single prediction to it.

# %%
# Test loading saved model
loaded_model = pickle.load(open(file_loc_name, 'rb'))
# Create a test value for test prediction
# Test value has to be contained in a numpy array format hence np.array
test_val = np.array(63)
# Reshaping value before feeding to .predict function
test_val_reshape = test_val.reshape(-1, 1)
# Conduct prediction
result = loaded_model.predict(test_val_reshape)
# Print out result
print(result)
# Out:
# [172249.3081752]

# %% [markdown]
# Now that we have exported this model, time to create a simple API (Application Programming Interface) that allows us to use the model, potentially remotely. On to [deployment](./sg-hdb-part3-basic-deployment-reference.ipynb)!
